# %% [markdown]
# # Uplift And Budget Review
#
# Reads saved uplift metrics, ranking curves, and budget simulation outputs.

# %%
from pathlib import Path
import json
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd()
REPORTS = ROOT / "reports"
FIGURES = REPORTS / "figures"

# %%
with (REPORTS / "uplift_metrics.json").open() as handle:
    uplift_metrics = json.load(handle)
with (REPORTS / "budget_simulation.json").open() as handle:
    budget_metrics = json.load(handle)
uplift_metrics, budget_metrics

# %%
pd.read_csv(REPORTS / "uplift_curve.csv").head(), pd.read_csv(REPORTS / "budget_simulation_curve.csv").head()

# %%
for name in [
    "uplift_cumulative_gain.png",
    "uplift_qini.png",
    "budget_allocation_comparison.png",
]:
    display(Image(filename=str(FIGURES / name)))
