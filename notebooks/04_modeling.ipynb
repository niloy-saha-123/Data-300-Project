# %% [markdown]
# # Modeling Review
#
# Loads saved model tables and exported figures. No training logic lives here.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd()
REPORTS = ROOT / "reports"
FIGURES = REPORTS / "figures"

# %%
validation = pd.read_csv(REPORTS / "validation_model_comparison.csv")
test = pd.read_csv(REPORTS / "model_comparison_table.csv")
validation, test
# Out:
# (                 model  optimal_threshold   roc_auc        f1  precision  \
#  0              xgboost           0.319882  0.785344  0.647045   0.542182
#  1        random_forest           0.461705  0.783082  0.643601   0.534002
#  2  logistic_regression           0.388936  0.741870  0.606550   0.491017
#  3       majority_class           0.500000  0.500000  0.000000   0.000000
#  4           rule_based           0.500000  0.500000  0.000000   0.000000
#
#       recall  average_precision
#  0  0.802198           0.624278
#  1  0.809806           0.626005
#  2  0.793181           0.572399
#  3  0.000000                NaN
#  4  0.000000                NaN  ,
#                   model   roc_auc  average_precision        f1  precision  \
#  0       majority_class  0.500000           0.322506  0.000000   0.000000
#  1           rule_based  0.500000           0.322506  0.000000   0.000000
#  2  logistic_regression  0.745817           0.538148  0.589636   0.469146
# ...

# %%
for name in [
    "roc_curves.png",
    "precision_recall_curves.png",
    "confusion_matrices.png",
    "logistic_regression_feature_importance.png",
    "random_forest_feature_importance.png",
    "xgboost_feature_importance.png",
    "shap_summary.png",
]:
    display(Image(filename=str(FIGURES / name)))
