# %% [markdown]
# # Clustering Review
#
# Reads saved segment tables and clustering figures.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd()
REPORTS = ROOT / "reports"
FIGURES = REPORTS / "figures"

# %%
profiles = pd.read_csv(REPORTS / "cluster_profiles.csv")
responses = pd.read_csv(REPORTS / "cluster_offer_response.csv")
profiles, responses

# %%
for name in [
    "kmeans_elbow.png",
    "kmeans_silhouette.png",
    "cluster_profile_heatmap.png",
    "cluster_offer_response_heatmap.png",
]:
    display(Image(filename=str(FIGURES / name)))
